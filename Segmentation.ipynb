# %% [markdown]
# <a href="https://colab.research.google.com/github/ghostman-007/Major-Project/blob/Bug-FIx/Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = cv2.imread('/content/drive/My Drive/Colab Notebooks/Images/string.jpeg')
(h, w) = img.shape[:2]
image_size = h*w
mser = cv2.MSER_create()
mser.setMaxArea(int(image_size/2))
mser.setMinArea(10)

regions, rects = mser.detectRegions(bw)

# With the rects you can e.g. crop the letters
for (x, y, w, h) in rects:
    cv2.rectangle(img, (x, y), (x+w, y+h), color=(255, 0, 255), thickness=1)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.imshow(img, cmap=plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# ### To grayscale

# %%
def rgb2gray(rgb):
  return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

img = mpimg.imread('/content/drive/My Drive/Colab Notebooks/Images/string.jpeg')
gray = rgb2gray(img)
plt.imshow(gray, cmap=plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# ### To convert image to black background

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
(thresh, img_bin) = cv2.threshold(gray, 128.0, 255.0, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

img_bin = 255-img_bin
plt.imshow(img_bin, cmap=plt.get_cmap('gray'))
plt.show()
